# %% [markdown]
# ## **SETD2 with SAM, analysis**

# %% [markdown]
# ## **Import modules**

# %%
import os
import sys

data_path=os.path.abspath('/media/dataHog/hca/SETD2') #Where your group data is
base_path=os.path.abspath('/media/dataHog/hca/SimFound_v2/source/') #Where your source code is (SFv2)

sys.path.append(base_path)
sys.path.append(data_path)

import importlib

import warnings
warnings.filterwarnings('ignore')
import Protocols as P

import main
import tools
import Trajectory
import MSM
import Featurize as F
import Discretize


from simtk.unit import *

# %% [markdown]
# ## **Define Project**

# %%
importlib.reload(Trajectory)
importlib.reload(main)

workdir=data_path
results=workdir+'/results'
inputs=workdir+'inputs/structures/'

workdir=tools.Functions.fileHandler([workdir], _new=False)
tools.Functions.fileHandler([results, inputs])


#protein=['WT', 'R167Q', 'I602G']
protein=['setd2_open']

ligand=['SAM']
parameters=['310K']
timestep=20*picoseconds

project=main.Project(title='SETD2-SAM', 
                     hierarchy=('protein', 'ligand', 'parameter'), 
                     workdir=workdir,
                     parameter=parameters, 
                     replicas=25, 
                     protein=protein, 
                     ligand=ligand, 
                     results=results,
                     topology='wt_SETD2.pdb',
                     timestep=timestep,
                    initial_replica=1)


project_systems=project.setSystems()
# Out:
# Converted parameter "temperature" (in K) into scalar: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '1'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '2'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '3'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '4'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '5'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '6'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '7'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '8'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '9'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '10'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '11'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '12'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '13'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '14'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '15'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '16'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '17'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '18'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '19'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '20'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '21'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '22'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '23'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '24'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '25'), ID: 310.0 K

# %% [markdown]
# ## Featurization

# %%
import Featurize as F
importlib.reload(main)

importlib.reload(F)
importlib.reload(Trajectory)

featurized={}
featurize=F.Featurize(project_systems, results=results, timestep=timestep)
# Out:
# Results will be stored under:  /media/dataHog/hca/SETD2/results

# %%
ref_structures=['SETD2', 'SETD2_complexed_noSub']

for ref in ref_structures:

    featurize.calculate(('backbone', f'{project.def_input_struct}/{ref}.pdb'), 
                                       method='RMSD',  
                                       n_cores=12,
                                       feature_name=f'RMSD_bb_SETD2_vs_{ref}')
# Out:
# Selected method: RMSD using the function "rmsd_calculation"
# Performing rmsd_calculation tasks for 25 elements on 12 logical cores.
# Pooling results of 25 tasks..
# Featurization updated:  ['RMSD_bb_SETD2_vs_SETD2']
# Selected method: RMSD using the function "rmsd_calculation"
# Performing rmsd_calculation tasks for 25 elements on 12 logical cores.
# Pooling results of 25 tasks..
# Featurization updated:  ['RMSD_bb_SETD2_vs_SETD2', 'RMSD_bb_SETD2_vs_SETD2_complexed_noSub']

# %%
distance_SAM=['resid 248 and name ZN', 'resname SAM and name N6']

featurized[f'distance_SAM_Zn']=featurize.calculate(distance_SAM, 
                                                   method='distance', 
                                                   feature_name=f'SAM-Zn',
                                                   n_cores=12)
# Out:
# Selected method: distance using the function "distance_calculation"
# Performing distance_calculation tasks for 25 elements on 12 logical cores.
# setd2_open-SAM-310K-10
# 	Number of frames: 1928
# 	Selections: 1
# 	References: 1
# 	Limits: 4.71 and 7.34
# setd2_open-SAM-310K-9
# 	Number of frames: 2229
# 	Selections: 1
# 	References: 1
# 	Limits: 4.74 and 6.99
# setd2_open-SAM-310K-8
# 	Number of frames: 2911
# 	Selections: 1
# 	References: 1
# 	Limits: 4.68 and 7.08
# setd2_open-SAM-310K-5
# 	Number of frames: 2910
# 	Selections: 1
# 	References: 1
# 	Limits: 4.67 and 7.12
# setd2_open-SAM-310K-6
# 	Number of frames: 2913
# 	Selections: 1
# 	References: 1
# 	Limits: 4.64 and 7.22
# setd2_open-SAM-310K-7
# 	Number of frames: 2916
# 	Selections: 1
# 	References: 1
# 	Limits: 4.54 and 9.33
# setd2_open-SAM-310K-15
# 	Number of frames: 4005
# 	Selections: 1
# 	References: 1
# 	Limits: 4.58 and 6.65
# setd2_open-SAM-310K-4
# 	Number of frames: 2919
# 	Selections: 1
# 	References: 1
# 	Limits: 4.78 and 7.03
# setd2_open-SAM-310K-17
# 	Number of frames: 2876
# 	Selections: 1
# 	References: 1
# 	Limits: 4.69 and 11.19
# setd2_open-SAM-310K-14
# 	Number of frames: 4648
# 	Selections: 1
# 	References: 1
# 	Limits: 4.59 and 6.73
# setd2_open-SAM-310K-13
# 	Number of frames: 4795
# 	Selections: 1
# 	References: 1
# 	Limits: 4.45 and 7.05
# setd2_open-SAM-310K-16
# 	Number of frames: 2912
# 	Selections: 1
# 	References: 1
# 	Limits: 4.72 and 8.61
# setd2_open-SAM-310K-12
# 	Number of frames: 4817
# 	Selections: 1
# 	References: 1
# 	Limits: 4.72 and 7.22
# setd2_open-SAM-310K-19
# 	Number of frames: 2904
# 	Selections: 1
# 	References: 1
# 	Limits: 4.51 and 7.71
# setd2_open-SAM-310K-24
# 	Number of frames: 2721
# 	Selections: 1
# 	References: 1
# 	Limits: 4.61 and 6.72
# setd2_open-SAM-310K-23
# 	Number of frames: 2709
# 	Selections: 1
# 	References: 1
# 	Limits: 4.61 and 6.98
# setd2_open-SAM-310K-18
# 	Number of frames: 2895
# 	Selections: 1
# 	References: 1
# 	Limits: 4.66 and 6.85
# setd2_open-SAM-310K-11
# 	Number of frames: 4860
# 	Selections: 1
# 	References: 1
# 	Limits: 4.6 and 7.92
# setd2_open-SAM-310K-25
# 	Number of frames: 2712
# 	Selections: 1
# 	References: 1
# 	Limits: 4.78 and 7.12
# setd2_open-SAM-310K-20
# 	Number of frames: 2896
# 	Selections: 1
# 	References: 1
# 	Limits: 4.63 and 6.69
# setd2_open-SAM-310K-22
# 	Number of frames: 2692
# 	Selections: 1
# 	References: 1
# 	Limits: 4.74 and 7.15
# setd2_open-SAM-310K-21
# 	Number of frames: 2787
# 	Selections: 1
# 	References: 1
# 	Limits: 4.66 and 7.42
# setd2_open-SAM-310K-2
# 	Number of frames: 24999
# 	Selections: 1
# 	References: 1
# 	Limits: 4.58 and 7.53
# setd2_open-SAM-310K-3
# 	Number of frames: 24999
# 	Selections: 1
# 	References: 1
# 	Limits: 4.56 and 8.38
# setd2_open-SAM-310K-1
# 	Number of frames: 24999
# 	Selections: 1
# 	References: 1
# 	Limits: 4.57 and 7.2
# Pooling results of 25 tasks..
# Featurization updated:  ['RMSD_bb_SETD2_vs_SETD2', 'RMSD_bb_SETD2_vs_SETD2_complexed_noSub', 'SAM-Zn']

# %%
distance_R1670=['resid 1670 and name NH1', 'resname SAM and name SD']
featurized[f'distance_R1670_SAM']=featurize.calculate(distance_R1670, 
                                                      method='distance', 
                                                      feature_name=f'R1670_SAM', 
                                                      n_cores=4)
# Out:
# Selected method: distance using the function "distance_calculation"
# Performing distance_calculation tasks for 25 elements on 4 logical cores.
# setd2_open-SAM-310K-5
# 	Number of frames: 2910
# 	Selections: 1
# 	References: 1
# 	Limits: 14.81 and 20.01
# setd2_open-SAM-310K-7
# 	Number of frames: 2916
# 	Selections: 1
# 	References: 1
# 	Limits: 12.41 and 18.91
# setd2_open-SAM-310K-6
# 	Number of frames: 2913
# 	Selections: 1
# 	References: 1
# 	Limits: 12.79 and 19.25
# setd2_open-SAM-310K-8
# 	Number of frames: 2911
# 	Selections: 1
# 	References: 1
# 	Limits: 10.44 and 21.58
# setd2_open-SAM-310K-9
# 	Number of frames: 2229
# 	Selections: 1
# 	References: 1
# 	Limits: 14.92 and 19.97
# setd2_open-SAM-310K-10
# 	Number of frames: 1928
# 	Selections: 1
# 	References: 1
# 	Limits: 10.7 and 17.26
# setd2_open-SAM-310K-13
# 	Number of frames: 4795
# 	Selections: 1
# 	References: 1
# 	Limits: 9.04 and 17.42
# setd2_open-SAM-310K-1
# 	Number of frames: 24999
# 	Selections: 1
# 	References: 1
# 	Limits: 6.41 and 20.29
# setd2_open-SAM-310K-14
# 	Number of frames: 4648
# 	Selections: 1
# 	References: 1
# 	Limits: 13.59 and 21.62
# setd2_open-SAM-310K-11
# 	Number of frames: 4894
# 	Selections: 1
# 	References: 1
# 	Limits: 9.95 and 20.1
# setd2_open-SAM-310K-15
# 	Number of frames: 4005
# 	Selections: 1
# 	References: 1
# 	Limits: 11.94 and 24.37
# setd2_open-SAM-310K-3
# 	Number of frames: 24999
# 	Selections: 1
# 	References: 1
# 	Limits: 8.45 and 21.41
# setd2_open-SAM-310K-12
# 	Number of frames: 4817
# 	Selections: 1
# 	References: 1
# 	Limits: 12.21 and 19.94
# setd2_open-SAM-310K-16
# 	Number of frames: 2912
# 	Selections: 1
# 	References: 1
# 	Limits: 11.47 and 17.89
# setd2_open-SAM-310K-17
# 	Number of frames: 2876
# 	Selections: 1
# 	References: 1
# 	Limits: 11.35 and 20.18
# setd2_open-SAM-310K-4
# 	Number of frames: 2963
# 	Selections: 1
# 	References: 1
# 	Limits: 12.11 and 19.16
# setd2_open-SAM-310K-19
# 	Number of frames: 2904
# 	Selections: 1
# 	References: 1
# 	Limits: 12.3 and 17.13
# setd2_open-SAM-310K-18
# 	Number of frames: 2895
# 	Selections: 1
# 	References: 1
# 	Limits: 10.56 and 20.21
# setd2_open-SAM-310K-21
# 	Number of frames: 2814
# 	Selections: 1
# 	References: 1
# 	Limits: 12.76 and 20.0
# setd2_open-SAM-310K-23
# 	Number of frames: 2709
# 	Selections: 1
# 	References: 1
# 	Limits: 10.9 and 18.07
# setd2_open-SAM-310K-20
# 	Number of frames: 2896
# 	Selections: 1
# 	References: 1
# 	Limits: 12.32 and 18.58
# setd2_open-SAM-310K-22
# 	Number of frames: 2692
# 	Selections: 1
# 	References: 1
# 	Limits: 13.21 and 19.97
# setd2_open-SAM-310K-24
# 	Number of frames: 2721
# 	Selections: 1
# 	References: 1
# 	Limits: 11.62 and 17.99
# setd2_open-SAM-310K-25
# 	Number of frames: 2712
# 	Selections: 1
# 	References: 1
# 	Limits: 11.37 and 20.34
# setd2_open-SAM-310K-2
# 	Number of frames: 24999
# 	Selections: 1
# 	References: 1
# 	Limits: 8.65 and 20.99
# Pooling results of 25 tasks..
# Featurization updated:  ['RMSD_bb_SETD2_vs_SETD2', 'RMSD_bb_SETD2_vs_SETD2_complexed_noSub', 'SAM-Zn', 'R1670_SAM']

# %%
featurized['RMSF']=featurize.calculate('protein and name CA', 
                                       method='RMSF', 
                                       n_cores=12,
                                       feature_name=f'RMSF_Ca')
# Out:
# Selected method: RMSF using the function "rmsf_calculation"
# Performing rmsf_calculation tasks for 25 elements on 12 logical cores.
# Pooling results of 25 tasks..
# Featurization updated:  ['RMSD_bb_SETD2_vs_SETD2', 'RMSD_bb_SETD2_vs_SETD2_complexed_noSub', 'SAM-Zn', 'R1670_SAM', 'RMSF_Ca']

# %%
#distance_R1670_Y=['resid 1670 and name NH1', 'resid 1579 and name OH']
distance_LoopIN_SETcd=['resid 1697 and name CB', 'resid 1593 and name CB'] #144 
featurized[f'distance_postSET-SETcd']=featurize.calculate(distance_LoopIN_SETcd, 
                                                        method='distance', 
                                                        feature_name=f'postSET-SETcd',  
                                                        n_cores=8)
# Out:
# Selected method: distance using the function "distance_calculation"
# Performing distance_calculation tasks for 25 elements on 8 logical cores.
# setd2_open-SAM-310K-8
# 	Number of frames: 2911
# 	Selections: 1
# 	References: 1
# 	Limits: 17.83 and 42.02
# setd2_open-SAM-310K-7
# 	Number of frames: 2916
# 	Selections: 1
# 	References: 1
# 	Limits: 8.84 and 40.19
# setd2_open-SAM-310K-5
# 	Number of frames: 2910
# 	Selections: 1
# 	References: 1
# 	Limits: 15.3 and 36.43
# setd2_open-SAM-310K-6
# 	Number of frames: 2913
# 	Selections: 1
# 	References: 1
# 	Limits: 12.7 and 22.31
# setd2_open-SAM-310K-4
# 	Number of frames: 3019
# 	Selections: 1
# 	References: 1
# 	Limits: 12.19 and 43.02
# setd2_open-SAM-310K-9
# 	Number of frames: 2229
# 	Selections: 1
# 	References: 1
# 	Limits: 7.92 and 29.48
# setd2_open-SAM-310K-10
# 	Number of frames: 1928
# 	Selections: 1
# 	References: 1
# 	Limits: 18.61 and 35.07
# setd2_open-SAM-310K-1
# 	Number of frames: 24999
# 	Selections: 1
# 	References: 1
# 	Limits: 7.32 and 39.53
# setd2_open-SAM-310K-13
# 	Number of frames: 4795
# 	Selections: 1
# 	References: 1
# 	Limits: 14.65 and 31.51
# setd2_open-SAM-310K-15
# 	Number of frames: 4005
# 	Selections: 1
# 	References: 1
# 	Limits: 12.13 and 33.68
# setd2_open-SAM-310K-12
# 	Number of frames: 4817
# 	Selections: 1
# 	References: 1
# 	Limits: 21.24 and 40.49
# setd2_open-SAM-310K-16
# 	Number of frames: 2912
# 	Selections: 1
# 	References: 1
# 	Limits: 11.98 and 39.27
# setd2_open-SAM-310K-14
# 	Number of frames: 4648
# 	Selections: 1
# 	References: 1
# 	Limits: 8.55 and 30.45
# setd2_open-SAM-310K-11
# 	Number of frames: 4962
# 	Selections: 1
# 	References: 1
# 	Limits: 12.01 and 41.44
# setd2_open-SAM-310K-17
# 	Number of frames: 2876
# 	Selections: 1
# 	References: 1
# 	Limits: 22.9 and 40.05
# setd2_open-SAM-310K-3
# 	Number of frames: 24999
# 	Selections: 1
# 	References: 1
# 	Limits: 8.99 and 41.44
# setd2_open-SAM-310K-19
# 	Number of frames: 2904
# 	Selections: 1
# 	References: 1
# 	Limits: 8.91 and 31.54
# setd2_open-SAM-310K-20
# 	Number of frames: 2896
# 	Selections: 1
# 	References: 1
# 	Limits: 13.24 and 40.26
# setd2_open-SAM-310K-18
# 	Number of frames: 2895
# 	Selections: 1
# 	References: 1
# 	Limits: 20.95 and 40.22
# setd2_open-SAM-310K-21
# 	Number of frames: 2865
# 	Selections: 1
# 	References: 1
# 	Limits: 16.05 and 37.36
# setd2_open-SAM-310K-22
# 	Number of frames: 2692
# 	Selections: 1
# 	References: 1
# 	Limits: 19.43 and 42.14
# setd2_open-SAM-310K-23
# 	Number of frames: 2709
# 	Selections: 1
# 	References: 1
# 	Limits: 7.49 and 30.8
# setd2_open-SAM-310K-24
# 	Number of frames: 2721
# 	Selections: 1
# 	References: 1
# 	Limits: 11.75 and 40.29
# setd2_open-SAM-310K-25
# 	Number of frames: 2712
# 	Selections: 1
# 	References: 1
# 	Limits: 12.39 and 32.77
# setd2_open-SAM-310K-2
# 	Number of frames: 24999
# 	Selections: 1
# 	References: 1
# 	Limits: 4.68 and 28.13
# Pooling results of 25 tasks..
# Featurization updated:  ['RMSD_bb_SETD2_vs_SETD2', 'RMSD_bb_SETD2_vs_SETD2_complexed_noSub', 'SAM-Zn', 'R1670_SAM', 'RMSF_Ca', 'postSET-SETcd']

# %%
#sels=[2521, 2848, 2550, 3497, 2508]
#distances_alacarte=[]
#for sel in sels:
#    distances_alacarte.append(['index 4078', f'index {str(sel)}'])

#for idx, distance in enumerate(distances_alacarte, 1):
#    featurized[f'distance_SAM_{idx}']=featurize.calculate(distance, method='distance', feature_name=f'SAM-{idx}', start=0, n_cores=6)

# %%
#featurized['RDF']=featurize.calculate(['protein', 'resname HOH'], method='RDF', start=0, n_cores=2, feature_name=f'RDF_protein', equilibration=True, production=True)

# %%
#featurized['SASA']=featurize.calculate('protein', method='SASA', start=0, n_cores=2, feature_name=f'SASA_protein', equilibration=True, production=True)

# %%
for k, v in featurize.features.items():
    print(k)
    featurize.plot(input_df=v, level=2, feature_name=k, subplots_=False)
# Out:
# RMSD_bb_SETD2_vs_SETD2
# Feature RMSD_bb_SETD2_vs_SETD2 found.
# Selected method: RMSD using the function "rmsd_calculation"
# RMSD_bb_SETD2_vs_SETD2_complexed_noSub
# Feature RMSD_bb_SETD2_vs_SETD2_complexed_noSub found.
# Selected method: RMSD using the function "rmsd_calculation"
# SAM-Zn
# Feature SAM-Zn found.
# Selected method: distance using the function "distance_calculation"
# R1670_SAM
# Feature R1670_SAM found.
# Selected method: distance using the function "distance_calculation"
# RMSF_Ca
# Feature RMSF_Ca found.
# Selected method: RMSF using the function "rmsf_calculation"
# postSET-SETcd
# Feature postSET-SETcd found.
# Selected method: distance using the function "distance_calculation"

# %%
importlib.reload(MSM)
kinetic_models_={}

protein_regions = {'loop_IN' : 'resid 240 to 255',
                   'post_SET_domain' : 'resid 220 to 240',
                   'combined' : 'resid 220 to 254',
                   'loopIN_SETcd' : ('resid 248 and sidechain', 'resid 136 to 147 and sidechain'),
                    'SETcd_helix' : 'resid 136 to 147'}

features_to_extract=['torsions', 'positions', 'min_dist', 'contacts']

kinetics=MSM.MSM(project_systems, results=results, timestep=timestep, stride=1)
for name, region in protein_regions.items():
        kinetic_models_[name]=kinetics.calculate(region,
                                                 method='TICA',
                                                 features=features_to_extract, 
                                                 ft_name=name, 
                                                 lags=200)
# Out:
# Results will be stored under:  /media/dataHog/hca/SETD2/results
# Extracting feature:  torsions
# 	Loading data for 56 dimensions
# Extracting feature:  positions
# 	Loading data for 654 dimensions
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b158959d93c9> in <module>
#      16                                                  features=features_to_extract,
#      17                                                  ft_name=name,
# ---> 18                                                  lags=200)
#
# /media/dataHog/hca/SimFound_v2/source/MSM.py in calculate(self, inputs, method, evaluate, ft_name, features, lags, dim)
#     129                     tops_to_load.append(top)
#     130
# --> 131         features=self.load_features(tops_to_load[0], trajectories_to_load, features, inputs=inputs)
#     132         #self.features[ft_name]=features
#     133
#
# /media/dataHog/hca/SimFound_v2/source/MSM.py in load_features(topology, trajectories, features, inputs)
#     365                 #print(feat.describe())
#     366                 print(f'\tLoading data for {feat.dimension()} dimensions')
# --> 367                 data = pyemma.coordinates.load(trajectories, features=feat)
#     368                 features_list.append((data, f, feat.dimension()))
#     369
#
# ~/miniconda3/lib/python3.7/site-packages/pyemma/coordinates/api.py in load(trajfiles, features, top, stride, chunksize, **kw)
#     242                  or len(trajfiles) == 0)):
#     243         reader = create_file_reader(trajfiles, top, features, chunksize=cs, **kw)
# --> 244         trajs = reader.get_output(stride=stride)
#     245         if len(trajs) == 1:
#     246             return trajs[0]
#
# ~/miniconda3/lib/python3.7/site-packages/pyemma/coordinates/data/_base/datasource.py in get_output(self, dimensions, stride, skip, chunk)
#     404             pg.register(it.n_chunks, description='getting output of %s' % self.__class__.__name__)
#     405             with pg.context(), it:
# --> 406                 for itraj, chunk in it:
#     407                     i = slice(it.pos, it.pos + len(chunk))
#     408                     assert i.stop - i.start > 0
#
# ~/miniconda3/lib/python3.7/site-packages/pyemma/coordinates/data/_base/datasource.py in __next__(self)
#    1047         self._select_file(self._itraj)
#    1048         try:
# -> 1049             X = self._use_cols(self._next_chunk())
#    1050             self._t += len(X)
#    1051         except StopIteration as e:
#
# ~/miniconda3/lib/python3.7/site-packages/pyemma/coordinates/data/_base/datasource.py in _next_chunk(self)
#    1166             x = self._it._next_chunk()
#    1167         else:
# -> 1168             x = next(self._it)
#    1169         # We discard the trajectory index here for transformation
#    1170         if self.transform_function is not None:
#
# ~/miniconda3/lib/python3.7/site-packages/pyemma/coordinates/util/patches.py in __next__(self)
#     212             if self._extension not in _TOPOLOGY_EXTS:
#     213                 traj = self._f.read_as_traj(self._topology, n_frames=n_frames,
# --> 214                                             stride=self._stride, atom_indices=self._atom_indices, **self._kwargs)
#     215             else:
#     216                 traj = self._f.read_as_traj(n_frames=n_frames,
#
# mdtraj/formats/dcd/dcd.pyx in mdtraj.formats.dcd.DCDTrajectoryFile.read_as_traj()
#
# mdtraj/formats/dcd/dcd.pyx in mdtraj.formats.dcd.DCDTrajectoryFile.read()
#
# <__array_function__ internals> in all(*args, **kwargs)
#
# KeyboardInterrupt:
