# %% [markdown]
# ## **SETD2 with SAM**

# %% [markdown]
# ## **Import modules**

# %%
import os
import sys

data_path=os.path.abspath('/media/dataHog/hca/SETD2') #Where your group data is
base_path=os.path.abspath('/media/dataHog/hca/SimFound_v2/source/') #Where your source code is (SFv2)

sys.path.append(base_path)
sys.path.append(data_path)

import importlib

import warnings
warnings.filterwarnings('ignore')
import Protocols as P

import main
import tools
import Featurize as F


from simtk.unit import *

# %% [markdown]
# ## **Define Project**

# %%
importlib.reload(main)

workdir=data_path
results=workdir+'/results'
inputs=workdir+'inputs/structures/'

workdir=tools.Functions.fileHandler([workdir], _new=False)
tools.Functions.fileHandler([results, inputs])


#protein=['WT', 'R167Q', 'I602G']
protein=['setd2_open']

ligand=['SAM']
parameters=['310K']
timestep=20*picoseconds

project=main.Project(title='SETD2-SAM', 
                     hierarchy=('protein', 'ligand', 'parameter'), 
                     workdir=workdir,
                     parameter=parameters, 
                     replicas=10, 
                     protein=protein, 
                     ligand=ligand, 
                     results=results,
                     topology='wt_SETD2.pdb',
                     timestep=timestep,
                    initial_replica=4)


project_systems=project.setSystems()
# Out:
# Converted parameter "temperature" (in K) into scalar: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '4'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '5'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '6'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '7'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '8'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '9'), ID: 310.0 K
# System defined: ('setd2_open', 'SAM', '310K', '10'), ID: 310.0 K

# %% [markdown]
# ## **Simulation Protocol**

# %% [markdown]
# ## Set defaults

# %%
SETD2_variants={('A',1499): 'CYX',
                ('A',1501): 'CYX',
                ('A',1516): 'CYX',
                ('A',1520): 'CYX',
                ('A',1529): 'CYX',
                ('A',1533):'CYX',
                ('A',1539):'CYX',
                ('A',1631):'CYX',
                ('A',1678):'CYX',
                ('A',1680):'CYX',
                ('A',1685):'CYX'}

NPT_equilibration={'ensemble': 'NPT',
                'step': 5*nanoseconds, 
                'report': timestep, 
                'restrained_sets': {'selections': ['protein and backbone', 'resname ZNB', 'resname SAM'],
                                    'forces': [100*kilojoules_per_mole/angstroms, 150*kilojoules_per_mole/angstroms, 150*kilojoules_per_mole/angstroms]}}

NPT_production={'ensemble': 'NPT',
                'step': 500*nanoseconds, 
                'report': timestep}

# %% [markdown]
# ## Setup simulation protocol

# %%
importlib.reload(P)
importlib.reload(tools)
extra_pdb = ['ZNB_open.pdb', 'SAM.pdb']
#smiles = 'C[S+](CC[C@@H](C(=O)[O-])N)C[C@@H]1[C@H]([C@H]([C@@H](O1)N2C=NC3=C(N=CN=C32)N)O)O'
xml_files = ['protein.ff14SB.xml', 'tip4pew.xml', 'ZNB.xml', 'SAM.xml', 'bonded.xml', 'gaff.xml']




simulated_systems={}
for name, system in project_systems.items():

    if system.ligand == 'SAM':
    
        sim_tools=P.Protocols(workdir=system.name_folder, 
                              project_dir=project.workdir,
                              def_input_struct=project.def_input_struct,
                              def_input_ff=project.def_input_ff,
                             overwrite_mode=False)
    
        system_omm=sim_tools.pdb2omm(input_pdb=system.input_topology,
                                     extra_input_pdb=extra_pdb,
                                     ff_files=xml_files,
                                     protonate=True,
                                     solvate=True,
                                     pH_protein=7.0,
                                     name=name,
                                     residue_variants=SETD2_variants)
                                    #insert_molecules=True)
                                    #insert_smiles=smiles)
                                      
        simulated_systems[name]=system_omm
# Out:
# Setting openMM simulation protocols in /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate4
# 	Warning! Found conserved openMM system(s). /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate4/omm_1.pkl
# 	Overwrite False: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate4/omm_2.pkl (1)
# Warning: Unable to load toolkit 'OpenEye Toolkit'. The Open Force Field Toolkit does not require the OpenEye Toolkits, and can use RDKit/AmberTools instead. However, if you have a valid license for the OpenEye Toolkits, consider installing them for faster performance and additional file format support: https://docs.eyesopen.com/toolkits/python/quickstart-python/linuxosx.html OpenEye offers free Toolkit licenses for academics: https://www.eyesopen.com/academic-licensing
# 	Loaded openMM system:
# 	File: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate4/system.pdb,
# 	Topology: <Topology; 5 chains, 22147 residues, 91663 atoms, 47929 bonds>
# Setting openMM simulation protocols in /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate5
# 	Warning! Found conserved openMM system(s). /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate5/omm_1.pkl
# 	Overwrite False: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate5/omm_2.pkl (1)
# 	Loaded openMM system:
# 	File: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate5/system.pdb,
# 	Topology: <Topology; 5 chains, 22147 residues, 91663 atoms, 47929 bonds>
# Setting openMM simulation protocols in /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate6
# 	Warning! Found conserved openMM system(s). /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate6/omm_1.pkl
# 	Overwrite False: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate6/omm_2.pkl (1)
# 	Loaded openMM system:
# 	File: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate6/system.pdb,
# 	Topology: <Topology; 5 chains, 22147 residues, 91663 atoms, 47929 bonds>
# Setting openMM simulation protocols in /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate7
# 	Warning! Found conserved openMM system(s). /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate7/omm_1.pkl
# 	Overwrite False: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate7/omm_2.pkl (1)
# 	Loaded openMM system:
# 	File: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate7/system.pdb,
# 	Topology: <Topology; 5 chains, 22147 residues, 91663 atoms, 47929 bonds>
# Setting openMM simulation protocols in /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate8
# 	Warning! Found conserved openMM system(s). /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate8/omm_1.pkl
# 	Overwrite False: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate8/omm_2.pkl (1)
# 	Loaded openMM system:
# 	File: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate8/system.pdb,
# 	Topology: <Topology; 5 chains, 22147 residues, 91663 atoms, 47929 bonds>
# Setting openMM simulation protocols in /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate9
# 	Warning! Found conserved openMM system(s). /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate9/omm_1.pkl
# 	Overwrite False: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate9/omm_2.pkl (1)
# 	Loaded openMM system:
# 	File: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate9/system.pdb,
# 	Topology: <Topology; 5 chains, 22147 residues, 91663 atoms, 47929 bonds>
# Setting openMM simulation protocols in /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate10
# 	Warning! Found conserved openMM system(s). /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate10/omm_1.pkl
# 	Overwrite False: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate10/omm_2.pkl (1)
# 	Loaded openMM system:
# 	File: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate10/system.pdb,
# 	Topology: <Topology; 5 chains, 22147 residues, 91663 atoms, 47929 bonds>

# %% [markdown]
# ## **WARNING!** Run simulation(s)

# %%
importlib.reload(P)
importlib.reload(tools)

gpu_index='0'

simulations={}
for name, simulation in simulated_systems.items():  
    simulation.setSimulations(dt=0.002*picoseconds, 
                                  temperature = system.scalar,
                                  pH=7.0,
                                  friction = 1/picosecond,
                                  equilibrations=[NPT_equilibration],
                                  productions=[NPT_production],
                                  pressure=1*atmospheres,
                                  gpu_index=gpu_index)
    
    
    simulation.runSimulations(run_productions=True,  
                              compute_time=2,
                              reportFactor=0.05)        
    
    simulations[name]=simulation
# Out:
# The fastest platform is CUDA
# Selected GPU ID: 0
# Using platform CUDA, ID: 0
# Run mode:
# 	Overwrite: False
# 	Resume: True
# 	Compute time: 120 min
#
#
# Energy minimization
# 	A complete checkpoint was found.
# 	System final potential energy: -1278713.0401262334 kJ/mol
#
# EQ run 1: NPT
# 	A complete checkpoint was found.
# 	System final potential energy: -1036053.5527357822 kJ/mol
#
# Production run 1: NPT
# 	A timeout checkpoint was found.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate4/production_NPT-1_init.pdb
# 	System initial potential energy: -1036053.5038644467 kJ/mol
# 	Simulation time: 443013.68 ps out of 500000.0 ps = 221506840/250000000 steps
# 	Simulating for 2:00:00 (0:06:00 checkpoints)...
# 	Warning! Simulation terminated by timeout: 3236540/250000000 = 246763460 steps to complete.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate4/production_NPT-1_chk.pdb
# 	System final potential energy: -1033076.5836627344 kJ/mol
# The fastest platform is CUDA
# Selected GPU ID: 0
# Using platform CUDA, ID: 0
# Run mode:
# 	Overwrite: False
# 	Resume: True
# 	Compute time: 120 min
#
#
# Energy minimization
# 	A complete checkpoint was found.
# 	System final potential energy: -1279840.9117403422 kJ/mol
#
# EQ run 1: NPT
# 	A complete checkpoint was found.
# 	System final potential energy: -1035575.7173598986 kJ/mol
#
# Production run 1: NPT
# 	A timeout checkpoint was found.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate5/production_NPT-1_init.pdb
# 	System initial potential energy: -1035575.5178666711 kJ/mol
# 	Simulation time: 441707.4 ps out of 500000.0 ps = 220853700/250000000 steps
# 	Simulating for 2:00:00 (0:06:00 checkpoints)...
# 	Warning! Simulation terminated by timeout: 3234280/250000000 = 246765720 steps to complete.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate5/production_NPT-1_chk.pdb
# 	System final potential energy: -1035981.2647105372 kJ/mol
# The fastest platform is CUDA
# Selected GPU ID: 0
# Using platform CUDA, ID: 0
# Run mode:
# 	Overwrite: False
# 	Resume: True
# 	Compute time: 120 min
#
#
# Energy minimization
# 	A complete checkpoint was found.
# 	System final potential energy: -1278895.3975507868 kJ/mol
#
# EQ run 1: NPT
# 	A complete checkpoint was found.
# 	System final potential energy: -1034665.0714020617 kJ/mol
#
# Production run 1: NPT
# 	A timeout checkpoint was found.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate6/production_NPT-1_init.pdb
# 	System initial potential energy: -1034664.9804416168 kJ/mol
# 	Simulation time: 441613.44 ps out of 500000.0 ps = 220806720/250000000 steps
# 	Simulating for 2:00:00 (0:06:00 checkpoints)...
# 	Warning! Simulation terminated by timeout: 3240490/250000000 = 246759510 steps to complete.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate6/production_NPT-1_chk.pdb
# 	System final potential energy: -1035400.1741109975 kJ/mol
# The fastest platform is CUDA
# Selected GPU ID: 0
# Using platform CUDA, ID: 0
# Run mode:
# 	Overwrite: False
# 	Resume: True
# 	Compute time: 120 min
#
#
# Energy minimization
# 	A complete checkpoint was found.
# 	System final potential energy: -1279089.7330201734 kJ/mol
#
# EQ run 1: NPT
# 	A complete checkpoint was found.
# 	System final potential energy: -1034575.3689615149 kJ/mol
#
# Production run 1: NPT
# 	A timeout checkpoint was found.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate7/production_NPT-1_init.pdb
# 	System initial potential energy: -1034575.15816506 kJ/mol
# 	Simulation time: 441566.9 ps out of 500000.0 ps = 220783450/250000000 steps
# 	Simulating for 2:00:00 (0:06:00 checkpoints)...
# 	Warning! Simulation terminated by timeout: 3241720/250000000 = 246758280 steps to complete.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate7/production_NPT-1_chk.pdb
# 	System final potential energy: -1035292.059880198 kJ/mol
# The fastest platform is CUDA
# Selected GPU ID: 0
# Using platform CUDA, ID: 0
# Run mode:
# 	Overwrite: False
# 	Resume: True
# 	Compute time: 120 min
#
#
# Energy minimization
# 	A complete checkpoint was found.
# 	System final potential energy: -1279063.6922368165 kJ/mol
#
# EQ run 1: NPT
# 	A complete checkpoint was found.
# 	System final potential energy: -1033296.1884321831 kJ/mol
#
# Production run 1: NPT
# 	A timeout checkpoint was found.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate8/production_NPT-1_init.pdb
# 	System initial potential energy: -1033296.0653355345 kJ/mol
# 	Simulation time: 448224.22000000003 ps out of 500000.0 ps = 224112110/250000000 steps
# 	Simulating for 2:00:00 (0:06:00 checkpoints)...
# 	Warning! Simulation terminated by timeout: 3237360/250000000 = 246762640 steps to complete.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate8/production_NPT-1_chk.pdb
# 	System final potential energy: -1037616.1118880082 kJ/mol
# The fastest platform is CUDA
# Selected GPU ID: 0
# Using platform CUDA, ID: 0
# Run mode:
# 	Overwrite: False
# 	Resume: True
# 	Compute time: 120 min
#
#
# Energy minimization
# 	A complete checkpoint was found.
# 	System final potential energy: -1278927.1914861053 kJ/mol
#
# EQ run 1: NPT
# 	A complete checkpoint was found.
# 	System final potential energy: -1037535.2058093566 kJ/mol
#
# Production run 1: NPT
# 	A timeout checkpoint was found.
# 	PDB file generated: /media/dataHog/hca/SETD2/setd2_open-SAM-310K/replicate9/production_NPT-1_init.pdb
# 	System initial potential energy: -1037535.2758979397 kJ/mol
# 	Simulation time: 455331.62 ps out of 500000.0 ps = 227665810/250000000 steps
# 	Simulating for 2:00:00 (0:06:00 checkpoints)...

# %%
simulations
